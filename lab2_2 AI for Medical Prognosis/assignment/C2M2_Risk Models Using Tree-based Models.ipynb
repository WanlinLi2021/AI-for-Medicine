# %% [markdown]
# # Risk Models Using Tree-based Models
#
# Welcome to the second assignment of Course 2!

# %% [markdown]
# ## Outline
#
# - [1. Import Packages](#1)
# - [2. Load the Dataset](#2)
# - [3. Explore the Dataset](#3)
# - [4. Dealing with Missing Data](#4)
#     - [Exercise 1](#Ex-1)
# - [5. Decision Trees](#5)
#     - [Exercise 2](#Ex-2)
# - [6. Random Forests](#6)
#     - [Exercise 3](#Ex-3)
# - [7. Imputation](#7)
# - [8. Error Analysis](#8)
#     - [Exercise 4](#Ex-4)
# - [9. Imputation Approaches](#Ex-9)
#     - [Exercise 5](#Ex-5)
#     - [Exercise 6](#Ex-6)
# - [10. Comparison](#10)
# - [11. Explanations: SHAP](#)

# %% [markdown]
# In this assignment, you'll gain experience with tree based models by predicting the 10-year risk of death of individuals from the NHANES I epidemiology dataset (for a detailed description of this dataset you can check the [CDC Website](https://wwwn.cdc.gov/nchs/nhanes/nhefs/default.aspx/)). This is a challenging task and a great test bed for the machine learning methods we learned this week.
#
# As you go through the assignment, you'll learn about:
#
# - Dealing with Missing Data
#   - Complete Case Analysis.
#   - Imputation
# - Decision Trees
#   - Evaluation.
#   - Regularization.
# - Random Forests
#   - Hyperparameter Tuning.

# %% [markdown]
# <a name='1'></a>
# ## 1. Import Packages
#
# We'll first import all the common packages that we need for this assignment.
#
# - `shap` is a library that explains predictions made by machine learning models.
# - `sklearn` is one of the most popular machine learning libraries.
# - `itertools` allows us to conveniently manipulate iterable objects such as lists.
# - `pydotplus` is used together with `IPython.display.Image` to visualize graph structures such as decision trees.
# - `numpy` is a fundamental package for scientific computing in Python.
# - `pandas` is what we'll use to manipulate our data.
# - `seaborn` is a plotting library which has some convenient functions for visualizing missing data.
# - `matplotlib` is a plotting library.

# %%
import shap
import sklearn
import itertools
import pydotplus
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from IPython.display import Image 

from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer, SimpleImputer

# We'll also import some helper functions that will be useful later on.
from util import load_data, cindex

# %% [markdown]
# <a name='2'></a>
# ## 2. Load the Dataset

# %% [markdown]
# Run the next cell to load in the NHANES I epidemiology dataset. This dataset contains various features of hospital patients as well as their outcomes, i.e. whether or not they died within 10 years.

# %%
X_dev, X_test, y_dev, y_test = load_data(10)

# %% [markdown]
# The dataset has been split into a development set (or dev set), which we will use to develop our risk models, and a test set, which we will use to test our models.
#
# We further split the dev set into a training and validation set, respectively to train and tune our models, using a 75/25 split (note that we set a random state to make this split repeatable).

# %%
X_train, X_val, y_train, y_val = train_test_split(X_dev, y_dev, test_size=0.25, random_state=10)

# %% [markdown]
# <a name='3'></a>
# ## 3. Explore the Dataset
#
# The first step is to familiarize yourself with the data. Run the next cell to get the size of your training set and look at a small sample.

# %%
print("X_train shape: {}".format(X_train.shape))
X_train.head()
# Out:
# X_train shape: (5147, 18)
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 1599  43.0          84.0          637.0   1.0             49.3
# 2794  72.0          96.0          154.0   2.0             43.4
# 1182  54.0          78.0          205.0   1.0             43.8
# 6915  59.0          90.0          417.0   1.0             43.4
# 500   34.0          80.0          385.0   1.0             77.7
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 1599                10.0            5.0              253.0       134.0
# 2794                23.0            4.3              265.0       106.0
# 1182                12.0            4.2              206.0       180.0
# 6915                 9.0            4.5              327.0       114.0
# 500                  9.0            4.1              197.0        64.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 1599             1.59            7.7  1.0          NaN  490.0  27.3
# 2794             1.66            6.8  2.0        208.0  301.0  35.2
# 1182             1.67            6.6  2.0          NaN  363.0  49.6
# 6915             1.65            7.6  2.0          NaN  347.0  32.9
# 500              1.74            7.3  2.0          NaN  376.0  17.0
#
#       White blood cells        BMI  Pulse pressure
# 1599                9.1  25.803007            34.0
# 2794                6.0  33.394319           112.0
# 1182                5.9  20.278410            34.0
# 6915                6.1  32.917744            78.0
# 500                 8.2  30.743489            30.0

# %% [markdown]
# Our targets `y` will be whether or not the target died within 10 years. Run the next cell to see the target data series.

# %%
y_train.head(20)
# Out:
# 1599    False
# 2794     True
# 1182    False
# 6915    False
# 500     False
# 1188     True
# 9739    False
# 3266    False
# 6681    False
# 8822    False
# 5856     True
# 3415    False
# 9366    False
# 7975    False
# 1397    False
# 6809    False
# 9461    False
# 9374    False
# 1170     True
# 158     False
# Name: time, dtype: bool

# %% [markdown]
# Use the next cell to examine individual cases and familiarize yourself with the features.

# %%
i = 10
print(X_train.iloc[i,:])
print("\nDied within 10 years? {}".format(y_train.loc[y_train.index[i]]))
# Out:
# Age                    67.000000
# Diastolic BP           94.000000
# Poverty index         114.000000
# Race                    1.000000
# Red blood cells        43.800000
# Sedimentation rate     12.000000
# Serum Albumin           3.700000
# Serum Cholesterol     178.000000
# Serum Iron             73.000000
# Serum Magnesium         1.850000
# Serum Protein           7.000000
# Sex                     1.000000
# Systolic BP           140.000000
# TIBC                  311.000000
# TS                     23.500000
# White blood cells       4.300000
# BMI                    17.481227
# Pulse pressure         46.000000
# Name: 5856, dtype: float64
#
# Died within 10 years? True

# %% [markdown]
# <a name='4'></a>
# ## 4. Dealing with Missing Data
#
# Looking at our data in `X_train`, we see that some of the data is missing: some values in the output of the previous cell are marked as `NaN` ("not a number").
#
# Missing data is a common occurrence in data analysis, that can be due to a variety of reasons, such as measuring instrument malfunction, respondents not willing or not able to supply information, and errors in the data collection process.
#
# Let's examine the missing data pattern. `seaborn` is an alternative to `matplotlib` that has some convenient plotting functions for data analysis. We can use its `heatmap` function to easily visualize the missing data pattern.
#
# Run the cell below to plot the missing data:

# %%
sns.heatmap(X_train.isnull(), cbar=False)
plt.title("Training")
plt.show()

sns.heatmap(X_val.isnull(), cbar=False)
plt.title("Validation")
plt.show()

# %% [markdown]
# For each feature, represented as a column, values that are present are shown in black, and missing values are set in a light color.
#
# From this plot, we can see that many values are missing for systolic blood pressure (`Systolic BP`).

# %% [markdown]
# <a name='Ex-1'></a>
# ### Exercise 1
#
# In the cell below, write a function to compute the fraction of cases with missing data. This will help us decide how we handle this missing data in the future.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> The <code>pandas.DataFrame.isnull()</code> method is helpful in this case.</li>
#     <li> Use the <code>pandas.DataFrame.any()</code> method and set the <code>axis</code> parameter.</li>
#     <li> Divide the total number of rows with missing data by the total number of rows. Remember that in Python, <code>True</code> values are equal to 1.</li>
# </ul>
# </p>

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def fraction_rows_missing(df):
    '''
    Return percent of rows with any missing
    data in the dataframe. 
    
    Input:
        df (dataframe): a pandas dataframe with potentially missing data
    Output:
        frac_missing (float): fraction of rows with missing data
    '''
    ### START CODE HERE (REPLACE 'Pass' with your 'return' code) ###
    return df.isnull().any(axis=1).sum()/df.shape[0]
    ### END CODE HERE ###

# %% [markdown]
# Test your function by running the cell below.

# %%
df_test = pd.DataFrame({'a':[None, 1, 1, None], 'b':[1, None, 0, 1]})
print("Example dataframe:\n")
print(df_test)

print("\nComputed fraction missing: {}, expected: {}".format(fraction_rows_missing(df_test), 0.75))
print(f"Fraction of rows missing from X_train: {fraction_rows_missing(X_train):.3f}")
print(f"Fraction of rows missing from X_val: {fraction_rows_missing(X_val):.3f}")
print(f"Fraction of rows missing from X_test: {fraction_rows_missing(X_test):.3f}")
# Out:
# Example dataframe:
#
#      a    b
# 0  NaN  1.0
# 1  1.0  NaN
# 2  1.0  0.0
# 3  NaN  1.0
#
# Computed fraction missing: 0.75, expected: 0.75
# Fraction of rows missing from X_train: 0.699
# Fraction of rows missing from X_val: 0.704
# Fraction of rows missing from X_test: 0.000

# %% [markdown]
# We see that our train and validation sets have missing values, but luckily our test set has complete cases.

# %% [markdown]
# As a first pass, we will begin with a **complete case analysis**, dropping all of the rows with any missing data. Run the following cell to drop these rows from our train and validation sets.

# %%
X_train_dropped = X_train.dropna(axis='rows')
y_train_dropped = y_train.loc[X_train_dropped.index]
X_val_dropped = X_val.dropna(axis='rows')
y_val_dropped = y_val.loc[X_val_dropped.index]

# %% [markdown]
# <a name='5'></a>
# ## 5. Decision Trees
#
# Having just learned about decision trees, you choose to use a decision tree classifier. Use scikit-learn to build a decision tree for the hospital dataset using the train set.

# %%
dt = DecisionTreeClassifier(max_depth=None, random_state=10)
dt.fit(X_train_dropped, y_train_dropped)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=10, splitter='best')

# %% [markdown]
# Next we will evaluate our model. We'll use C-Index for evaluation.
#
# > Remember from lesson 4 of week 1 that the C-Index evaluates the ability of a model to differentiate between different classes, by quantifying how often, when considering all pairs of patients (A, B), the model says that patient A has a higher risk score than patient B when, in the observed data, patient A actually died and patient B actually lived. In our case, our model is a binary classifier, where each risk score is either 1 (the model predicts that the patient will die) or 0 (the patient will live).
# >
# > More formally, defining _permissible pairs_ of patients as pairs where the outcomes are different, _concordant pairs_ as permissible pairs where the patient that died had a higher risk score (i.e. our model predicted 1 for the patient that died and 0 for the one that lived), and _ties_ as permissible pairs where the risk scores were equal (i.e. our model predicted 1 for both patients or 0 for both patients), the C-Index is equal to:
# >
# > $$\text{C-Index} = \frac{\#\text{concordant pairs} + 0.5\times \#\text{ties}}{\#\text{permissible pairs}}$$
#
# Run the next cell to compute the C-Index on the train and validation set (we've given you an implementation this time).

# %%
y_train_preds = dt.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")


y_val_preds = dt.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.5629321808510638

# %% [markdown]
# Unfortunately your tree seems to be overfitting: it fits the training data so closely that it doesn't generalize well to other samples such as those from the validation set.
#
# > The training C-index comes out to 1.0 because, when initializing `DecisionTreeClasifier`, we have left `max_depth` and `min_samples_split` unspecified. The resulting decision tree will therefore keep splitting as far as it can, which pretty much guarantees a pure fit to the training data.
#
# To handle this, you can change some of the hyperparameters of our tree.

# %% [markdown]
# <a name='Ex-2'></a>
# ### Exercise 2
#
# Try and find a set of hyperparameters that improves the generalization to the validation set and recompute the C-index. If you do it right, you should get C-index above 0.6 for the validation set.
#
# You can refer to the documentation for the sklearn [DecisionTreeClassifier](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html).

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Try limiting the depth of the tree (<code>'max_depth'</code>).</li>
# </ul>
# </p>

# %%
# Experiment with different hyperparameters for the DecisionTreeClassifier
# until you get a c-index above 0.6 for the validation set
dt_hyperparams = {
    # set your own hyperparameters below, such as 'min_samples_split': 1

    ### START CODE HERE ###
    'max_depth':3,
    'min_samples_split':6
    
    
    
    
    ### END CODE HERE ###
}

# %% [markdown]
# Run the next cell to fit and evaluate the regularized tree.

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
dt_reg = DecisionTreeClassifier(**dt_hyperparams, random_state=10)
dt_reg.fit(X_train_dropped, y_train_dropped)

y_train_preds = dt_reg.predict_proba(X_train_dropped)[:, 1]
y_val_preds = dt_reg.predict_proba(X_val_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_preds)}")
print(f"Val C-Index (expected > 0.6): {cindex(y_val_dropped.values, y_val_preds)}")
# Out:
# Train C-Index: 0.688738755448391
# Val C-Index (expected > 0.6): 0.6302692819148936

# %% [markdown]
# If you used a low `max_depth` you can print the entire tree. This allows for easy interpretability. Run the next cell to print the tree splits.

# %%
dot_data = StringIO()
export_graphviz(dt_reg, feature_names=X_train_dropped.columns, out_file=dot_data,  
                filled=True, rounded=True, proportion=True, special_characters=True,
                impurity=False, class_names=['neg', 'pos'], precision=2)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# > **Overfitting, underfitting, and the bias-variance tradeoff**
# >
# > If you tested several values of `max_depth`, you may have seen that a value of `3` gives training and validation C-Indices of about `0.689` and `0.630`, and that a `max_depth` of `2` gives better agreement with values of about `0.653` and `0.607`. In the latter case, we have further reduced overfitting, at the cost of a minor loss in predictive performance.
# >
# > Contrast this with a `max_depth` value of `1`, which results in C-Indices of about `0.597` for the training set and `0.598` for the validation set: we have eliminated overfitting but with a much stronger degradation of predictive performance.
# >
# > Lower predictive performance on the training and validation sets is indicative of the model _underfitting_ the data: it neither learns enough from the training data nor is able to generalize to unseen data (the validation data in our case).
# >
# > Finding a model that minimizes and acceptably balances underfitting and overfitting (e.g. selecting the model with a `max_depth` of `2` over the other values) is a common problem in machine learning that is known as the _bias-variance tradeoff_.

# %% [markdown]
# <a name='6'></a>
# ## 6. Random Forests
#
# No matter how you choose hyperparameters, a single decision tree is prone to overfitting. To solve this problem, you can try **random forests**, which combine predictions from many different trees to create a robust classifier.
#
# As before, we will use scikit-learn to build a random forest for the data. We will use the default hyperparameters.

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=10)
rf.fit(X_train_dropped, y_train_dropped)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=10, verbose=0,
#                        warm_start=False)

# %% [markdown]
# Now compute and report the C-Index for the random forest on the training and validation set.

# %%
y_train_rf_preds = rf.predict_proba(X_train_dropped)[:, 1]
print(f"Train C-Index: {cindex(y_train_dropped.values, y_train_rf_preds)}")

y_val_rf_preds = rf.predict_proba(X_val_dropped)[:, 1]
print(f"Val C-Index: {cindex(y_val_dropped.values, y_val_rf_preds)}")
# Out:
# Train C-Index: 1.0
# Val C-Index: 0.6660488696808511

# %% [markdown]
# Training a random forest with the default hyperparameters results in a model that has better predictive performance than individual decision trees as in the previous section, but this model is overfitting.
#
# We therefore need to tune (or optimize) the hyperparameters, to find a model that both has good predictive performance and minimizes overfitting.
#
# The hyperparameters we choose to adjust will be:
#
# - `n_estimators`: the number of trees used in the forest.
# - `max_depth`: the maximum depth of each tree.
# - `min_samples_leaf`: the minimum number (if `int`) or proportion (if `float`) of samples in a leaf.
#
# The approach we implement to tune the hyperparameters is known as a grid search:
#
# - We define a set of possible values for each of the target hyperparameters.
#
# - A model is trained and evaluated for every possible combination of hyperparameters.
#
# - The best performing set of hyperparameters is returned.
#
# The cell below implements a hyperparameter grid search, using the C-Index to evaluate each tested model.

# %%
def holdout_grid_search(clf, X_train_hp, y_train_hp, X_val_hp, y_val_hp, hyperparams, fixed_hyperparams={}):
    '''
    Conduct hyperparameter grid search on hold out validation set. Use holdout validation.
    Hyperparameters are input as a dictionary mapping each hyperparameter name to the
    range of values they should iterate over. Use the cindex function as your evaluation
    function.

    Input:
        clf: sklearn classifier
        X_train_hp (dataframe): dataframe for training set input variables
        y_train_hp (dataframe): dataframe for training set targets
        X_val_hp (dataframe): dataframe for validation set input variables
        y_val_hp (dataframe): dataframe for validation set targets
        hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                            names to range of values for grid search
        fixed_hyperparams (dict): dictionary of fixed hyperparameters that
                                  are not included in the grid search

    Output:
        best_estimator (sklearn classifier): fitted sklearn classifier with best performance on
                                             validation set
        best_hyperparams (dict): hyperparameter dictionary mapping hyperparameter
                                 names to values in best_estimator
    '''
    best_estimator = None
    best_hyperparams = {}
    
    # hold best running score
    best_score = 0.0

    # get list of param values
    lists = hyperparams.values()
    
    # get all param combinations
    param_combinations = list(itertools.product(*lists))
    total_param_combinations = len(param_combinations)

    # iterate through param combinations
    for i, params in enumerate(param_combinations, 1):
        # fill param dict with params
        param_dict = {}
        for param_index, param_name in enumerate(hyperparams):
            param_dict[param_name] = params[param_index]
            
        # create estimator with specified params
        estimator = clf(**param_dict, **fixed_hyperparams)

        # fit estimator
        estimator.fit(X_train_hp, y_train_hp)
        
        # get predictions on validation set
        preds = estimator.predict_proba(X_val_hp)
        
        # compute cindex for predictions
        estimator_score = cindex(y_val_hp, preds[:,1])

        print(f'[{i}/{total_param_combinations}] {param_dict}')
        print(f'Val C-Index: {estimator_score}\n')

        # if new high score, update high score, best estimator
        # and best params 
        if estimator_score >= best_score:
                best_score = estimator_score
                best_estimator = estimator
                best_hyperparams = param_dict

    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_estimator, best_hyperparams

# %% [markdown]
# <a name='Ex-3'></a>
# ### Exercise 3
#
# In the cell below, define the values you want to run the hyperparameter grid search on, and run the cell to find the best-performing set of hyperparameters.
#
# Your objective is to get a C-Index above `0.6` on both the train and validation set.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
def random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped):

    # Define ranges for the chosen random forest hyperparameters 
    hyperparams = {
        
        ### START CODE HERE (REPLACE array values with your code) ###

        # how many trees should be in the forest (int)
        'n_estimators': [1,10,50,100],

        # the maximum depth of trees in the forest (int)
        
        'max_depth': [2,3,4,5,6,7,8],
        
        # the minimum number of samples in a leaf as a fraction
        # of the total number of samples in the training set
        # Can be int (in which case that is the minimum number)
        # or float (in which case the minimum is that fraction of the
        # number of training set samples)
        'min_samples_leaf': [1,2,3,4],

        ### END CODE HERE ###
    }

    
    fixed_hyperparams = {
        'random_state': 10,
    }
    
    rf = RandomForestClassifier

    best_rf, best_hyperparams = holdout_grid_search(rf, X_train_dropped, y_train_dropped,
                                                    X_val_dropped, y_val_dropped, hyperparams,
                                                    fixed_hyperparams)

    print(f"Best hyperparameters:\n{best_hyperparams}")

    
    y_train_best = best_rf.predict_proba(X_train_dropped)[:, 1]
    print(f"Train C-Index: {cindex(y_train_dropped, y_train_best)}")

    y_val_best = best_rf.predict_proba(X_val_dropped)[:, 1]
    print(f"Val C-Index: {cindex(y_val_dropped, y_val_best)}")
    
    # add fixed hyperparamters to best combination of variable hyperparameters
    best_hyperparams.update(fixed_hyperparams)
    
    return best_rf, best_hyperparams

# %%
best_rf, best_hyperparams = random_forest_grid_search(X_train_dropped, y_train_dropped, X_val_dropped, y_val_dropped)
# Out:
# [1/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.5285738031914894
#
# [2/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.5285738031914894
#
# [3/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.5285738031914894
#
# [4/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.5199966755319149
#
# [5/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.5938912898936171
#
# [6/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.5938912898936171
#
# [7/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.5938912898936171
#
# [8/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.5856299867021276
#
# [9/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.53671875
#
# [10/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.53671875
#
# [11/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.53671875
#
# [12/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.5321143617021277
#
# [13/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.590093085106383
#
# [14/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.5961436170212766
#
# [15/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.5959275265957447
#
# [16/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.6152011303191489
#
# [17/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 1}
# Val C-Index: 0.5946891622340426
#
# [18/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.581781914893617
#
# [19/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.5980385638297873
#
# [20/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.5449800531914893
#
# [21/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 1}
# Val C-Index: 0.6068816489361702
#
# [22/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.5655086436170212
#
# [23/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.572514960106383
#
# [24/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.5673786569148936
#
# [25/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 1}
# Val C-Index: 0.549468085106383
#
# [26/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.5590093085106383
#
# [27/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 3}
# Val C-Index: 0.5637882313829787
#
# [28/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.5705867686170213
#
# [29/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6350398936170213
#
# [30/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6350398936170213
#
# [31/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6350398936170213
#
# [32/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6331615691489362
#
# [33/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6508394281914893
#
# [34/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6487117686170213
#
# [35/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6487117686170213
#
# [36/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6490608377659575
#
# [37/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6489527925531915
#
# [38/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6560172872340425
#
# [39/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6533494015957447
#
# [40/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6446476063829787
#
# [41/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.6594414893617021
#
# [42/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.6452875664893617
#
# [43/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.6584441489361702
#
# [44/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.6629404920212766
#
# [45/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 1}
# Val C-Index: 0.6723071808510638
#
# [46/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.6633228058510638
#
# [47/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.649642619680851
#
# [48/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.656998005319149
#
# [49/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 1}
# Val C-Index: 0.6651761968085106
#
# [50/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.6393617021276595
#
# [51/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.6733876329787234
#
# [52/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.6343085106382979
#
# [53/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 1}
# Val C-Index: 0.643783244680851
#
# [54/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.6081283244680851
#
# [55/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 3}
# Val C-Index: 0.6297041223404255
#
# [56/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.6521110372340425
#
# [57/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6595744680851063
#
# [58/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6595744680851063
#
# [59/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6598570478723405
#
# [60/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6602892287234042
#
# [61/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6724567819148937
#
# [62/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6722240691489362
#
# [63/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6725066489361702
#
# [64/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6725897606382979
#
# [65/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.6665724734042553
#
# [66/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6681349734042553
#
# [67/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6666223404255319
#
# [68/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6624833776595744
#
# [69/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.6637965425531915
#
# [70/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.6655585106382979
#
# [71/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.659624335106383
#
# [72/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.6578789893617021
#
# [73/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 1}
# Val C-Index: 0.665907579787234
#
# [74/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.67734375
#
# [75/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.6701462765957447
#
# [76/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.6652094414893617
#
# [77/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 1}
# Val C-Index: 0.6784574468085106
#
# [78/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.6714428191489362
#
# [79/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.6740857712765957
#
# [80/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.6727892287234043
#
# [81/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 1}
# Val C-Index: 0.6610039893617021
#
# [82/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.6544381648936171
# [83/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 3}
# Val C-Index: 0.6589926861702128
#
# [84/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.6647107712765957
#
# [85/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 1}
# Val C-Index: 0.6626662234042553
#
# [86/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6626662234042553
#
# [87/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 3}
# Val C-Index: 0.6629654255319148
#
# [88/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6630984042553192
#
# [89/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 1}
# Val C-Index: 0.6782579787234042
#
# [90/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.6778257978723404
#
# [91/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 3}
# Val C-Index: 0.6772273936170212
#
# [92/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.6771110372340425
#
# [93/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 1}
# Val C-Index: 0.668783244680851
#
# [94/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6695644946808511
#
# [95/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 3}
# Val C-Index: 0.6712599734042554
#
# [96/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6732047872340425
#
# [97/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 1}
# Val C-Index: 0.6687666223404255
#
# [98/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.672157579787234
#
# [99/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 3}
# Val C-Index: 0.6697972074468085
#
# [100/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.6693317819148936
#
# [101/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 1}
# Val C-Index: 0.6714594414893617
#
# [102/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.6815824468085107
#
# [103/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 3}
# Val C-Index: 0.6719248670212766
#
# [104/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.6714594414893617
#
# [105/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 1}
# Val C-Index: 0.6738530585106383
#
# [106/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.6707945478723404
#
# [107/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 3}
# Val C-Index: 0.6712932180851063
#
# [108/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.6732047872340425
#
# [109/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 1}
# Val C-Index: 0.6664394946808511
#
# [110/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.6634973404255319
#
# [111/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 3}
# Val C-Index: 0.6660904255319149
#
# [112/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.6696476063829787
#
# Best hyperparameters:
# {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 2, 'random_state': 10}
# Train C-Index: 0.9076435129370305
# Val C-Index: 0.6815824468085107

# %% [markdown]
# Finally, evaluate the model on the test set. This is a crucial step, as trying out many combinations of hyperparameters and evaluating them on the validation set could result in a model that ends up overfitting the validation set. We therefore need to check if the model performs well on unseen data, which is the role of the test set, which we have held out until now.

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
y_test_best = best_rf.predict_proba(X_test)[:, 1]

print(f"Test C-Index: {cindex(y_test.values, y_test_best)}")
# Out:
# Test C-Index: 0.7033859330829922

# %% [markdown]
# Your C-Index on the test set should be greater than `0.6`.

# %% [markdown]
# <a name='7'></a>
# ## 7. Imputation
#
# You've now built and optimized a random forest model on our data. However, there was still a drop in test C-Index. This might be because you threw away more than half of the data of our data because of missing values for systolic blood pressure. Instead, we can try filling in, or imputing, these values.
#
# First, **let's explore to see if our data is missing at random or not.** Let's **plot histograms of the dropped rows against each of the covariates** (aside from systolic blood pressure) to see if there is a trend. Compare these to the histograms of the feature in the entire dataset. Try to see if one of the covariates has a signficantly different distribution in the two subsets.

# %%
dropped_rows = X_train[X_train.isnull().any(axis=1)]

columns_except_Systolic_BP = [col for col in X_train.columns if col not in ['Systolic BP']]

for col in columns_except_Systolic_BP:
    sns.distplot(X_train.loc[:, col], norm_hist=True, kde=False, label='full data')
    sns.distplot(dropped_rows.loc[:, col], norm_hist=True, kde=False, label='without missing data')
    plt.legend()

    plt.show()

# %% [markdown]
# Most of the covariates are distributed similarly whether or not we have discarded rows with missing data. In other words missingness of the data is independent of these covariates.
#
# If this had been true across *all* covariates, then the data would have been said to be **missing completely at random (MCAR)**.
#
# But when considering the age covariate, we see that much more data tends to be missing for patients over 65. The reason could be that blood pressure was measured less frequently for old people to avoid placing additional burden on them.
#
# As missingness is related to one or more covariates, the missing data is said to be **missing at random (MAR)**.
#
# Based on the information we have, there is however no reason to believe that the _values_ of the missing data — or specifically the values of the missing systolic blood pressures — are related to the age of the patients.
# If this was the case, then this data would be said to be **missing not at random (MNAR)**.

# %% [markdown]
# <a name='8'></a>
# ## 8. Error Analysis
#
# <a name='Ex-4'></a>
# ### Exercise 4
# Using the information from the plots above, try to find a subgroup of the test data on which the model performs poorly. You should be able to easily find a subgroup of at least 250 cases on which the model has a C-Index of less than 0.69.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li> Define a mask using a feature and a threshold, e.g. patients with a BMI below 20: <code>mask = X_test['BMI'] < 20 </code>. </li>
#     <li> Try to find a subgroup for which the model had little data.</li>
# </ul>
# </p>

# %%
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def bad_subset(forest, X_test, y_test):
    # define mask to select large subset with poor performance
    # currently mask defines the entire set
    
    ### START CODE HERE (REPLACE the code after 'mask =' with your code) ###
    mask = X_test["Age"] > 66
    ### END CODE HERE ###

    X_subgroup = X_test[mask]
    y_subgroup = y_test[mask]
    subgroup_size = len(X_subgroup)

    y_subgroup_preds = forest.predict_proba(X_subgroup)[:, 1]
    performance = cindex(y_subgroup.values, y_subgroup_preds)
    
    return performance, subgroup_size

# %% [markdown]
# #### Test Your Work

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print("Subgroup size should greater than 250, performance should be less than 0.69 ")
print(f"Subgroup size: {subgroup_size}, C-Index: {performance}")
# Out:
# Subgroup size should greater than 250, performance should be less than 0.69
# Subgroup size: 372, C-Index: 0.6851371440230857

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# - Make sure that the c-index is less than 0.69
# ```Python
# Subgroup size: 586, C-Index: 0.6275
# ```
#
# **Bonus**:
# - See if you can get a c-index as low as 0.53
# ```
# Subgroup size: 251, C-Index: 0.5331
# ```

# %% [markdown]
# <a name='9'></a>
# ## 9. Imputation Approaches
#
# Seeing that our data is not missing completely at random, we can handle the missing values by **replacing them with substituted values based on the other values that we have**. This is known as imputation.
#
# The first imputation strategy that we will use is **mean substitution**: we will replace the missing values for each feature with the mean of the available values. In the next cell, use the `SimpleImputer` from `sklearn` to use mean imputation for the missing values.

# %%
# Impute values using the mean
imputer = SimpleImputer(strategy='mean')
imputer.fit(X_train)
X_train_mean_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_mean_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)

# %% [markdown]
# <a name='Ex-5'></a>
# ### Exercise 5
# Now perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set.
#
# Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
# Make your test c-index at least 0.74 or higher

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': [1,10,50,100],

    # the maximum depth of trees in the forest (int)
    'max_depth': [2,3,4,5,6,7,8],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [2,4,6,8],

    ### END CODE HERE ###
}

# %%
# UNQ_C5 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_mean_imputed, best_hyperparams_mean_imputed = holdout_grid_search(rf, X_train_mean_imputed, y_train,
                                                                     X_val_mean_imputed, y_val,
                                                                     hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_mean_imputed.predict_proba(X_train_mean_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_mean_imputed.predict_proba(X_val_mean_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_mean_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.6890404504287367
#
# [2/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.6890404504287367
#
# [3/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.6890404504287367
#
# [4/112] {'n_estimators': 1, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.6890404504287367
#
# [5/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7065655677369344
#
# [6/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7065655677369344
#
# [7/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7065655677369344
#
# [8/112] {'n_estimators': 1, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7065655677369344
#
# [9/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.6940421983805932
#
# [10/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.6935178128236696
#
# [11/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7108214505177629
#
# [12/112] {'n_estimators': 1, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7065916241621231
#
# [13/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.694788063551621
#
# [14/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.6892608443584582
#
# [15/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.6988800079906371
#
# [16/112] {'n_estimators': 1, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.6981525994541179
#
# [17/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7054505698757325
#
# [18/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.6974707896616791
#
# [19/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.704093464397152
#
# [20/112] {'n_estimators': 1, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7081854088361681
#
# [21/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.6385897828414098
#
# [22/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.6858224819179266
#
# [23/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.6856466010479025
#
# [24/112] {'n_estimators': 1, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.6882902425201775
#
# [25/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.6529816150206605
#
# [26/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.6622924442881059
#
# [27/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.6677338944150224
#
# [28/112] {'n_estimators': 1, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.6954416455501055
#
# [29/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7166928316602937
#
# [30/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7166928316602937
#
# [31/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7166928316602937
#
# [32/112] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.7166928316602937
#
# [33/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7271794571143811
#
# [34/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7266322721854175
#
# [35/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7266344435541833
#
# [36/112] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7263912502524216
#
# [37/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7404204638477957
#
# [38/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7415843175062264
#
# [39/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7430054783633959
#
# [40/112] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7424376654311579
#
# [41/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.745648034151288
#
# [42/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7438913968198133
#
# [43/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7473265022071963
#
# [44/112] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.7474524415956086
#
# [45/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.751237137354274
#
# [46/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7391111284820613
#
# [47/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7457262034268541
#
# [48/112] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7558208968187277
#
# [49/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.723569556541357
#
# [50/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7417677981669305
#
# [51/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.734612052399471
#
# [52/112] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7431705023895914
#
# [53/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.7423225828865742
#
# [54/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.7406875422059804
#
# [55/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7395041462286581
#
# [56/112] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.753776553125794
#
# [57/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7344622279546358
#
# [58/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7337000775178649
#
# [59/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7337000775178649
#
# [60/112] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.7335426532823496
#
# [61/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7368930752878692
#
# [62/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7363252623556311
#
# [63/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7363676040465629
#
# [64/112] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7375846562397539
#
# [65/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7461213925422169
#
# [66/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.744493951652303
#
# [67/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7445558356621264
#
# [68/112] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7443397844699363
#
# [69/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7462071616084631
#
# [70/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7515237580313502
#
# [71/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7495347842419426
#
# [72/112] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.7508386911857627
#
# [73/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7552845687335926
#
# [74/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7542173409852369
#
# [75/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7504587016517602
#
# [76/112] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7511980527164909
#
# [77/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7429359945628926
#
# [78/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7489137727749441
#
# [79/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7476826066847759
#
# [80/112] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7538601508232745
#
# [81/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.7472548470379273
# [82/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.7508962324580546
#
# [83/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7458412859714378
#
# [84/112] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.7526637266333579
#
# [85/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.732025952199488
#
# [86/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7315851643400451
#
# [87/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7315178519083074
#
# [88/112] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.7316926470939487
#
# [89/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7357161934168441
#
# [90/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7351896364911549
#
# [91/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7352048360725151
#
# [92/112] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7359995570407718
#
# [93/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7437448294281266
#
# [94/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7431542171238483
#
# [95/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7428817103437494
#
# [96/112] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7434820938074734
#
# [97/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7471299933338978
#
# [98/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7476066087779754
#
# [99/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7464840111260935
#
# [100/112] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.7488681740308638
#
# [101/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7522207674051492
#
# [102/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7525464727200085
#
# [103/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7516627256323569
#
# [104/112] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7511958813477252
#
# [105/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7453809557931033
#
# [106/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.749851804081739
#
# [107/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7509592021522608
#
# [108/112] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7545311037718847
#
# [109/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.748642351679228
#
# [110/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.7521035134917998
#
# [111/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7536755844781875
#
# [112/112] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.7538232375542571
#
# Performance for best hyperparameters:
# - Train C-Index: 0.8185
# - Val C-Index: 0.7558
# - Test C-Index: 0.7684

# %% [markdown]
# #### Expected output
# Note, your actual c-index values will vary depending on the hyper-parameters that you choose.
# - Try to get a good Test c-index, similar these numbers below:
#
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8109
# - Val C-Index: 0.7495
# - Test C-Index: 0.7805
# ```

# %% [markdown]
# Next, we will apply another imputation strategy, known as **multivariate feature imputation**, using scikit-learn's `IterativeImputer` class (see the [documentation](https://scikit-learn.org/stable/modules/impute.html#iterative-imputer)).
#
# With this strategy, for each feature that is missing values, a regression model is trained to predict observed values based on all of the other features, and the missing values are inferred using this model.
# As a single iteration across all features may not be enough to impute all missing values, several iterations may be performed, hence the name of the class `IterativeImputer`.
#
# In the next cell, use `IterativeImputer` to perform multivariate feature imputation.
#
# > Note that the first time the cell is run, `imputer.fit(X_train)` may fail with the message `LinAlgError: SVD did not converge`: simply re-run the cell.

# %%
# Impute using regression on other covariates
imputer = IterativeImputer(random_state=0, sample_posterior=False, max_iter=1, min_value=0)
imputer.fit(X_train)
X_train_imputed = pd.DataFrame(imputer.transform(X_train), columns=X_train.columns)
X_val_imputed = pd.DataFrame(imputer.transform(X_val), columns=X_val.columns)

# %% [markdown]
# <a name='Ex-6'></a>
# ### Exercise 6
#
# Perform a hyperparameter grid search to find the best-performing random forest model, and report results on the test set. Define the parameter ranges for the hyperparameter search in the next cell, and run the cell.
#
# #### Target performance
#
# Try to get a text c-index of at least 0.74 or higher.

# %% [markdown]
# <details>
# <summary>
#     <font size="3" color="darkgreen"><b>Hints</b></font>
# </summary>
# <p>
# <ul>
#     <li>n_estimators: try values greater than 100</li>
#     <li>max_depth: try values in the range 1 to 100</li>
#     <li>min_samples_leaf: try float values below .5 and/or int values greater than 2</li>
# </ul>
# </p>

# %%
# Define ranges for the random forest hyperparameter search 
hyperparams = {
    ### START CODE HERE (REPLACE array values with your code) ###

    # how many trees should be in the forest (int)
    'n_estimators': [10,25,50,75,100],

    # the maximum depth of trees in the forest (int)
    'max_depth': [2,3,4,5,6,7,8],

    # the minimum number of samples in a leaf as a fraction
    # of the total number of samples in the training set
    # Can be int (in which case that is the minimum number)
    # or float (in which case the minimum is that fraction of the
    # number of training set samples)
    'min_samples_leaf': [2,4,6,8],

    ### END CODE HERE ###
}

# %%
# UNQ_C6 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
rf = RandomForestClassifier

rf_imputed, best_hyperparams_imputed = holdout_grid_search(rf, X_train_imputed, y_train,
                                                           X_val_imputed, y_val,
                                                           hyperparams, {'random_state': 10})

print("Performance for best hyperparameters:")

y_train_best = rf_imputed.predict_proba(X_train_imputed)[:, 1]
print(f"- Train C-Index: {cindex(y_train, y_train_best):.4f}")

y_val_best = rf_imputed.predict_proba(X_val_imputed)[:, 1]
print(f"- Val C-Index: {cindex(y_val, y_val_best):.4f}")

y_test_imp = rf_imputed.predict_proba(X_test)[:, 1]
print(f"- Test C-Index: {cindex(y_test, y_test_imp):.4f}")
# Out:
# [1/140] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7144508934096787
#
# [2/140] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7144508934096787
#
# [3/140] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7144508934096787
#
# [4/140] {'n_estimators': 10, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.7144508934096787
#
# [5/140] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7232134520637774
#
# [6/140] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7226673528191966
#
# [7/140] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.722680381031791
#
# [8/140] {'n_estimators': 10, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7224274165705836
#
# [9/140] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7333830576780686
#
# [10/140] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7334438560035089
#
# [11/140] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7347705623193692
#
# [12/140] {'n_estimators': 10, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7383174931981873
#
# [13/140] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7436286611991602
#
# [14/140] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7424821784908553
#
# [15/140] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7443452128918506
#
# [16/140] {'n_estimators': 10, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.7411771858626522
#
# [17/140] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7347510200004777
#
# [18/140] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7342288058123199
#
# [19/140] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7278113254252083
#
# [20/140] {'n_estimators': 10, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7357140220480785
#
# [21/140] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7245325585889577
#
# [22/140] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7257430966758516
#
# [23/140] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7273553379844052
#
# [24/140] {'n_estimators': 10, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7344296574231498
#
# [25/140] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.733371115149857
#
# [26/140] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.7278221822690369
#
# [27/140] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7268244383211845
#
# [28/140] {'n_estimators': 10, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.7363795465747743
#
# [29/140] {'n_estimators': 25, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7256736128753483
#
# [30/140] {'n_estimators': 25, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7256736128753483
#
# [31/140] {'n_estimators': 25, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7256736128753483
#
# [32/140] {'n_estimators': 25, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.7256736128753483
#
# [33/140] {'n_estimators': 25, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7268798082247107
#
# [34/140] {'n_estimators': 25, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.726332623295747
#
# [35/140] {'n_estimators': 25, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7264433631027991
#
# [36/140] {'n_estimators': 25, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7268407235869275
#
# [37/140] {'n_estimators': 25, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7395888296105216
#
# [38/140] {'n_estimators': 25, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.737495630120359
#
# [39/140] {'n_estimators': 25, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7390069027813062
#
# [40/140] {'n_estimators': 25, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7398157376465403
#
# [41/140] {'n_estimators': 25, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7449369108805117
#
# [42/140] {'n_estimators': 25, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7435320352890852
#
# [43/140] {'n_estimators': 25, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7432302150306489
#
# [44/140] {'n_estimators': 25, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.744014079155077
#
# [45/140] {'n_estimators': 25, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7463765283721899
#
# [46/140] {'n_estimators': 25, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7473330163134936
#
# [47/140] {'n_estimators': 25, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7472863318850304
#
# [48/140] {'n_estimators': 25, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7405594314488024
#
# [49/140] {'n_estimators': 25, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.740963306039228
#
# [50/140] {'n_estimators': 25, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7450226799467581
#
# [51/140] {'n_estimators': 25, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.737151468170991
#
# [52/140] {'n_estimators': 25, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7472374760878014
#
# [53/140] {'n_estimators': 25, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.7423920666870776
#
# [54/140] {'n_estimators': 25, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.7416158023533295
#
# [55/140] {'n_estimators': 25, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7387582810576303
#
# [56/140] {'n_estimators': 25, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.7484968699719242
#
# [57/140] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7348997587609302
#
# [58/140] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7343015466659718
#
# [59/140] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7343015466659718
#
# [60/140] {'n_estimators': 50, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.734132179902245
#
# [61/140] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.735573968762689
#
# [62/140] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7347379917878833
#
# [63/140] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7349529572956904
#
# [64/140] {'n_estimators': 50, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7357151077324613
#
# [65/140] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7454569536999038
#
# [66/140] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7440955054837918
#
# [67/140] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7431075326953852
#
# [68/140] {'n_estimators': 50, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7430869046921108
#
# [69/140] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7463124729936009
#
# [70/140] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7493893025346388
#
# [71/140] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.744934739511746
#
# [72/140] {'n_estimators': 50, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.7465990936706772
#
# [73/140] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7521501979202629
#
# [74/140] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7505596702993667
#
# [75/140] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7481928783447221
#
# [76/140] {'n_estimators': 50, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7455394657130016
#
# [77/140] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7472787320943504
#
# [78/140] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7465882368268485
#
# [79/140] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7441302473840434
#
# [80/140] {'n_estimators': 50, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7512045668227881
#
# [81/140] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.7465013820762194
# [82/140] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.7476891207910731
#
# [83/140] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7470550811114802
#
# [84/140] {'n_estimators': 50, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.7518885479839926
#
# [85/140] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7302215447551673
#
# [86/140] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.7299783514534057
#
# [87/140] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7299783514534057
#
# [88/140] {'n_estimators': 75, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.7299664089251942
#
# [89/140] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.7340844097893989
#
# [90/140] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7334883690632064
#
# [91/140] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7338379594344887
#
# [92/140] {'n_estimators': 75, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.734163664749348
#
# [93/140] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7409329068765077
#
# [94/140] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7400350458918789
#
# [95/140] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7392229539734962
#
# [96/140] {'n_estimators': 75, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.739841794071729
#
# [97/140] {'n_estimators': 75, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7441335044371921
#
# [98/140] {'n_estimators': 75, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7442540154036901
#
# [99/140] {'n_estimators': 75, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7440151648394598
#
# [100/140] {'n_estimators': 75, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.7446991460006644
#
# [101/140] {'n_estimators': 75, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7490983391200311
#
# [102/140] {'n_estimators': 75, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7488160611804864
#
# [103/140] {'n_estimators': 75, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7500732836958434
#
# [104/140] {'n_estimators': 75, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7467337185341524
#
# [105/140] {'n_estimators': 75, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7474741552832659
#
# [106/140] {'n_estimators': 75, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7462951020434752
#
# [107/140] {'n_estimators': 75, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7443647552107422
#
# [108/140] {'n_estimators': 75, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7481755073945964
#
# [109/140] {'n_estimators': 75, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.7471897059749555
#
# [110/140] {'n_estimators': 75, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.7472852462006475
#
# [111/140] {'n_estimators': 75, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7509939440525124
#
# [112/140] {'n_estimators': 75, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.751293592942183
#
# [113/140] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 2}
# Val C-Index: 0.7288177548481236
#
# [114/140] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 4}
# Val C-Index: 0.728389995201275
#
# [115/140] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 6}
# Val C-Index: 0.7283682815136178
#
# [116/140] {'n_estimators': 100, 'max_depth': 2, 'min_samples_leaf': 8}
# Val C-Index: 0.7282846838161372
#
# [117/140] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 2}
# Val C-Index: 0.733226719126936
#
# [118/140] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 4}
# Val C-Index: 0.7325264526999885
#
# [119/140] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 6}
# Val C-Index: 0.7326893053574182
#
# [120/140] {'n_estimators': 100, 'max_depth': 3, 'min_samples_leaf': 8}
# Val C-Index: 0.7330182677254261
#
# [121/140] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 2}
# Val C-Index: 0.7409003363450218
#
# [122/140] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 4}
# Val C-Index: 0.7401512141208454
#
# [123/140] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 6}
# Val C-Index: 0.7391502131198443
#
# [124/140] {'n_estimators': 100, 'max_depth': 4, 'min_samples_leaf': 8}
# Val C-Index: 0.7399623050382269
#
# [125/140] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 2}
# Val C-Index: 0.7447208596883217
#
# [126/140] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 4}
# Val C-Index: 0.7433290123094896
#
# [127/140] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 6}
# Val C-Index: 0.7429099381377039
#
# [128/140] {'n_estimators': 100, 'max_depth': 5, 'min_samples_leaf': 8}
# Val C-Index: 0.7451811898666563
#
# [129/140] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 2}
# Val C-Index: 0.7480430538998869
#
# [130/140] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 4}
# Val C-Index: 0.7486314948353994
#
# [131/140] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 6}
# Val C-Index: 0.7503273338414336
#
# [132/140] {'n_estimators': 100, 'max_depth': 6, 'min_samples_leaf': 8}
# Val C-Index: 0.7480452252686526
#
# [133/140] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 2}
# Val C-Index: 0.7480452252686526
#
# [134/140] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 4}
# Val C-Index: 0.7498626609255676
#
# [135/140] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 6}
# Val C-Index: 0.7465252671326424
#
# [136/140] {'n_estimators': 100, 'max_depth': 7, 'min_samples_leaf': 8}
# Val C-Index: 0.7483796160585748
#
# [137/140] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 2}
# Val C-Index: 0.7479388281991319
#
# [138/140] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 4}
# Val C-Index: 0.748258019407694
#
# [139/140] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 6}
# Val C-Index: 0.7511285689159876
#
# [140/140] {'n_estimators': 100, 'max_depth': 8, 'min_samples_leaf': 8}
# Val C-Index: 0.7518016932333635
#
# Performance for best hyperparameters:
# - Train C-Index: 0.8421
# - Val C-Index: 0.7522
# - Test C-Index: 0.7793

# %% [markdown]
# #### Expected Output
# Note, your actual output will vary depending on the hyper-parameters that you chose and the mask that you chose.
# ```Python
# Performance for best hyperparameters:
# - Train C-Index: 0.8131
# - Val C-Index: 0.7454
# - Test C-Index: 0.7797
# ```

# %% [markdown]
# <a name='10'></a>
# ## 10. Comparison
#
# For good measure, retest on the subgroup from before to see if your new models do better.

# %%
performance, subgroup_size = bad_subset(best_rf, X_test, y_test)
print(f"C-Index (no imputation): {performance}")

performance, subgroup_size = bad_subset(rf_mean_imputed, X_test, y_test)
print(f"C-Index (mean imputation): {performance}")

performance, subgroup_size = bad_subset(rf_imputed, X_test, y_test)
print(f"C-Index (multivariate feature imputation): {performance}")
# Out:
# C-Index (no imputation): 0.6851371440230857
# C-Index (mean imputation): 0.6660156819308013
# C-Index (multivariate feature imputation): 0.6794531728218731

# %% [markdown]
# We should see that avoiding complete case analysis (i.e. analysis only on observations for which there is no missing data) allows our model to generalize a bit better. Remember to examine your missing cases to judge whether they are missing at random or not!

# %% [markdown]
# <a name='11'></a>
# ## 11. Explanations: SHAP
#
# Using a random forest has improved results, but we've lost some of the natural interpretability of trees. In this section we'll try to explain the predictions using slightly more sophisticated techniques.
#
# You choose to apply **SHAP (SHapley Additive exPlanations)**, a cutting edge method that explains predictions made by black-box machine learning models (i.e. models which are too complex to be understandable by humans as is).
#
# > Given a prediction made by a machine learning model, SHAP values explain the prediction by quantifying the additive importance of each feature to the prediction. SHAP values have their roots in cooperative game theory, where Shapley values are used to quantify the contribution of each player to the game.
# >
# > Although it is computationally expensive to compute SHAP values for general black-box models, in the case of trees and forests there exists a fast polynomial-time algorithm. For more details, see the [TreeShap paper](https://arxiv.org/pdf/1802.03888.pdf).
#
# We'll use the [shap library](https://github.com/slundberg/shap) to do this for our random forest model. Run the next cell to output the most at risk individuals in the test set according to our model.

# %%
X_test_risk = X_test.copy(deep=True)
X_test_risk.loc[:, 'risk'] = rf_imputed.predict_proba(X_test_risk)[:, 1]
X_test_risk = X_test_risk.sort_values(by='risk', ascending=False)
X_test_risk.head()
# Out:
#        Age  Diastolic BP  Poverty index  Race  Red blood cells  \
# 5493  67.0          80.0           30.0   1.0             77.7
# 6609  72.0          90.0           75.0   1.0             29.3
# 2044  74.0          80.0           83.0   1.0             47.6
# 2608  71.0          80.0          104.0   1.0             43.8
# 3237  72.0          90.0           42.0   2.0             44.0
#
#       Sedimentation rate  Serum Albumin  Serum Cholesterol  Serum Iron  \
# 5493                59.0            3.4              231.0        36.0
# 6609                59.0            3.9              216.0        64.0
# 2044                19.0            4.2              205.0        72.0
# 2608                23.0            4.0              201.0       119.0
# 3237                45.0            3.8              228.0        59.0
#
#       Serum Magnesium  Serum Protein  Sex  Systolic BP   TIBC    TS  \
# 5493             1.40            6.3  1.0        170.0  202.0  17.8
# 6609             1.63            7.4  2.0        182.0  322.0  19.9
# 2044             1.71            6.9  1.0        180.0  310.0  23.2
# 2608             1.60            7.0  1.0        166.0  311.0  38.3
# 3237             1.47            7.8  2.0        166.0  311.0  19.0
#
#       White blood cells        BMI  Pulse pressure      risk
# 5493                8.4  17.029470            90.0  0.594811
# 6609                9.3  22.281793            92.0  0.582835
# 2044               10.8  20.900101           100.0  0.576096
# 2608                6.3  17.760766            86.0  0.566194
# 3237               10.7  32.808172            76.0  0.555439

# %% [markdown]
# We can use SHAP values to try and understand the model output on specific individuals using force plots. Run the cell below to see a force plot on the riskiest individual.

# %%
explainer = shap.TreeExplainer(rf_imputed)
i = 0
shap_value = explainer.shap_values(X_test.loc[X_test_risk.index[i], :])[1]
shap.force_plot(explainer.expected_value[1], shap_value, feature_names=X_test.columns, matplotlib=True)

# %% [markdown]
# How to read this chart:
# - The red sections on the left are features which push the model towards the final prediction in the positive direction (i.e. a higher Age increases the predicted risk).
# - The blue sections on the right are features that push the model towards the final prediction in the negative direction (if an increase in a feature leads to a lower risk, it will be shown in blue).
# - Note that the exact output of your chart will differ depending on the hyper-parameters that you choose for your model.
#
# We can also use SHAP values to understand the model output in aggregate. Run the next cell to initialize the SHAP values (this may take a few minutes).

# %%
shap_values = shap.TreeExplainer(rf_imputed).shap_values(X_test)[1]

# %% [markdown]
# Run the next cell to see a summary plot of the SHAP values for each feature on each of the test examples. The colors indicate the value of the feature.

# %%
shap.summary_plot(shap_values, X_test)

# %% [markdown]
# Clearly we see that being a woman (`sex = 2.0`, as opposed to men for which `sex = 1.0`) has a negative SHAP value, meaning that it reduces the risk of dying within 10 years. High age and high systolic blood pressure have positive SHAP values, and are therefore related to increased mortality.
#
# You can see how features interact using dependence plots. These plot the SHAP value for a given feature for each data point, and color the points in using the value for another feature. This lets us begin to explain the variation in SHAP value for a single value of the main feature.
#
# Run the next cell to see the interaction between Age and Sex.

# %%
shap.dependence_plot('Age', shap_values, X_test, interaction_index='Sex')

# %% [markdown]
# We see that while Age > 50 is generally bad (positive SHAP value), being a woman generally reduces the impact of age. This makes sense since we know that women generally live longer than men.
#
# Let's now look at poverty index and age.

# %%
shap.dependence_plot('Poverty index', shap_values, X_test, interaction_index='Age')

# %% [markdown]
# We see that the impact of poverty index drops off quickly, and for higher income individuals age begins to explain much of variation in the impact of poverty index.
#
# Try some other pairs and see what other interesting relationships you can find!

# %% [markdown]
# # Congratulations!
#
# You have completed the second assignment in Course 2. Along the way you've learned to fit decision trees, random forests, and deal with missing data. Now you're ready to move on to week 3!
